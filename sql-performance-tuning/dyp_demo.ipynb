# %%
# %%time

import os
import glob
import pandas as pd
import psycopg2

base_dir = 'data/toyota_sales_10years'

files = sorted(glob.glob(os.path.join(base_dir, '*.csv')))

conn = "postgresql://postgres:perfdemo123@34.58.132.114:5432/performance_tuning"

# Read one file at a time and load into Postgres database
for file in files[:36]:
    print(f"Loading {file}")
    df = pd.read_csv(file)
    df.to_sql('toyota_sales', conn, if_exists='append', index=False)
# Out:
# CPU times: user 7.46 s, sys: 2.97 s, total: 10.4 s
# Wall time: 52.6 s

# %%
# %%time

from dyp_demo import main

main(num_files=150, max_workers=16)
# Out:
# Found 135 files to load
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_10.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_05.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2015_03.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_11.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_06.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_02.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_09.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_01.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2015_04.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2015_02.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_08.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_12.csv
# Successfully loaded data/toyota_sales_10years/toyota_sales_2014_07.csv
# ...
